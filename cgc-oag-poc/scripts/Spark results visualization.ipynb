# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('data.csv', ';', header=0)

# %%
data
# Out:
#                username  firstName     lastName  \
# 0         ludwig.hoeger    Alessia     Gottlieb
# 1         kenny.waelchi   Anabelle       Murphy
# 2          may.tremblay   Makenzie    Rodriguez
# 3       everett.reinger     Miller  Schamberger
# 4          kelley.weber      Elsie        Robel
# 5       hadley.schulist   Immanuel    Greenholt
# 6         lavada.kemmer    Christa      Barrows
# 7           holly.weber    Forrest       Little
# 8      abelardo.shields  Sylvester       Sawayn
# 9       jeanie.gottlieb    Mariela         Howe
# 10          gus.gerhold   Magnolia     Nitzsche
# 11        izaiah.wunsch        Edd      Johnson
# 12      domenick.corwin     Fausto      Okuneva
# 13  kayleigh.williamson    Rozella   Jakubowski
# 14     kathryne.hegmann        Dax      Smitham
# 15         evans.raynor     Weldon        Emard
# 16           luz.spinka    Candice        Crona
# 17       deangelo.pagac      Aidan         Rice
# ...

# %%
data['price']
# Out:
# 0     91.23
# 1     77.98
# 2     87.32
# 3     16.69
# 4     74.65
# 5     40.18
# 6     88.25
# 7     54.08
# 8     69.64
# 9      3.27
# 10     0.88
# 11    96.95
# 12    86.95
# 13    93.58
# 14    53.29
# 15    79.52
# 16    79.67
# 17    80.70
# 18    33.77
# 19    99.35
# 20    13.07
# 21    29.10
# 22    38.57
# 23    46.42
# 24    76.15
# 25    23.55
# 26    53.31
# 27    93.73
# 28    35.07
# 29    82.57
# 30    82.70
# 31    25.39
# 32    37.99
# 33    16.53
# 34    92.21
# 35    19.49
# 36    28.40
# 37    42.11
# 38    24.82
# 39    75.84
# 40    22.15
# 41    44.30
# 42    71.37
# 43    82.37
# 44    10.91
# 45    35.87
# 46    49.38
# 47    26.80
# 48    74.53
# 49    29.45
# 50    price
# 51    48.65
# Name: price, dtype: object

# %%
data['username']
# Out:
# 0           ludwig.hoeger
# 1           kenny.waelchi
# 2            may.tremblay
# 3         everett.reinger
# 4            kelley.weber
# 5         hadley.schulist
# 6           lavada.kemmer
# 7             holly.weber
# 8        abelardo.shields
# 9         jeanie.gottlieb
# 10            gus.gerhold
# 11          izaiah.wunsch
# 12        domenick.corwin
# 13    kayleigh.williamson
# 14       kathryne.hegmann
# 15           evans.raynor
# 16             luz.spinka
# 17         deangelo.pagac
# 18        marquis.collier
# 19         reynold.dooley
# 20            drew.glover
# 21            joaquin.toy
# 22        briana.thompson
# 23           keyon.walker
# 24             jerel.dare
# 25              king.ward
# 26         carole.stroman
# 27        idell.langworth
# 28            erik.murphy
# 29          shyann.muller
# 30        michael.gerlach
# 31            reva.hamill
# 32           mollie.hintz
# 33         robert.hegmann
# 34       emmett.marquardt
# ...

# %%
data.loc[50]
# Out:
# username              username
# firstName            firstName
# lastName              lastName
# fullAddress        fullAddress
# streetAddress    streetAddress
# productName        productName
# price                    price
# phoneNumber        phoneNumber
# orderDate            orderDate
# B0                          B0
# B1                          B1
# B2                          B2
# B3                          B3
# B4                          B4
# B5                          B5
# B6                          B6
# B7                          B7
# B8                          B8
# B9                          B9
# B10                        B10
# B11                        B11
# B12                        B12
# B13                        B13
# B14                        B14
# B15                        B15
# B16                        B16
# B17                        B17
# B18                        B18
# B19                        B19
# B20                        B20
# ...

# %%
data2 = pd.read_csv('result-spark-sql-2/part-00000-77f18543-66ff-4ce0-86a5-414103cf04e9-c000.csv', sep=',')

# %%
data2
# Out:
#              Unnamed: 0 Unnamed: 1   Unnamed: 2  \
# 0           gus.gerhold   Magnolia     Nitzsche
# 1       jeanie.gottlieb    Mariela         Howe
# 2        jazmyne.deckow       Alva       Turner
# 3           drew.glover    Gilbert       Larson
# 4        robert.hegmann   Makenzie   Gusikowski
# 5       everett.reinger     Miller  Schamberger
# 6     alexander.jenkins    Chesley         Mann
# 7          ellie.hammes     Aubrey        Lakin
# 8             king.ward    Wendell       Walker
# 9     estevan.schroeder     Jettie      D'Amore
# 10          reva.hamill   Terrence        Green
# 11      horacio.keebler     Summer         Feil
# 12        kendra.zemlak    Forrest   McLaughlin
# 13          joaquin.toy    Gillian        Braun
# 14      gwendolyn.kutch   Marquise        Dicki
# 15      marquis.collier     Rupert       Herman
# 16          erik.murphy        Ova     Gorczany
# 17      breanne.volkman      Frank       Herman
# ...

# %%
data2 = data.sort(columns='price')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-57fbfa007921> in <module>()
# ----> 1 data2 = data.sort(columns='price')
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
data?
